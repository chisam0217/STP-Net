# %%
import numpy as np
import sys
import os

from rrt_star import RRTStar
from search_space import SearchSpace
from utilities.plotting import Plot
import os.path as op
import time

arr_dir = "../../Data/3D_map/Map_array"
# total_maz = np.load(op.join(arr_dir, 'maz.npy'))
obs = np.load(op.join(arr_dir, 'obs.npy'))
train_config = np.load(op.join(arr_dir, 'train_config.npy'))
test_seen_config = np.load(op.join(arr_dir, 'test_seen_config.npy'))
test_unseen_config = np.load(op.join(arr_dir, 'test_unseen_config.npy'))

# %%
def RRTstar(Obstacles, configuration):

    X_dimensions = np.array([(0, 19), (0, 19), (0, 19)])  # dimensions of Search Space
    x_init = (configuration[0], configuration[1], configuration[2])

    x_goal = (configuration[3], configuration[4], configuration[5])

    # print ('x_init', x_init)
    # print ('x_goal', x_goal)


    Q = np.array([(2,1)])  # length of tree edges
    r = 1  # length of smallest edge to check for intersection with obstacles
    max_samples = 1024  # max number of samples to take before timing out
    rewire_count = 3  # optional, number of nearby branches to rewire
    prc = 0.1  # probability of checking for a connection to goal

    # create Search Space
    X = SearchSpace(X_dimensions, Obstacles)
# create rrt_search
    rrt = RRTStar(X, Q, x_init, x_goal, max_samples, r, prc, rewire_count)
    path = rrt.rrt_star()
    if path is None:
        return None
    path = np.array(path, dtype=np.int)
    return path

# %%
s_time = time.time()
map100_train = []
for i in range(100):
    print ('map', i)
#     for j in range(5):
    for j in range(train_config.shape[1]):
        # print ('j', j)
#         print ('train_config[i,j]', train_config[i,j])
        waypoints = RRTstar(obs[i], train_config[i,j])
        if waypoints is not None:
            print ('waypoints', waypoints.shape[0])
            map100_train.append(waypoints)
        else:
            map100_train.append(map100_train[-1])
            

print ('The total time is', time.time() - s_time)
# Out:
# map 0
# waypoints 5
# waypoints 5
# waypoints 3
# waypoints 7
# waypoints 5
# waypoints 4
# waypoints 6
# waypoints 8
# waypoints 6
# waypoints 7
# waypoints 3
# waypoints 5
# waypoints 3
# waypoints 8
# waypoints 3
# waypoints 7
# waypoints 7
# waypoints 8
# waypoints 3
# waypoints 5
# waypoints 6
# waypoints 6
# waypoints 5
# waypoints 3
# waypoints 4
# waypoints 5
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 5
# waypoints 10
# waypoints 5
# waypoints 4
# waypoints 3
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 5
# waypoints 6
# waypoints 7
# waypoints 7
# waypoints 8
# waypoints 5
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 4
# waypoints 8
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 3
# waypoints 5
# waypoints 7
# waypoints 8
# waypoints 5
# waypoints 8
# waypoints 5
# waypoints 5
# waypoints 10
# waypoints 6
# waypoints 7
# waypoints 5
# waypoints 4
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 5
# waypoints 6
# waypoints 8
# waypoints 4
# waypoints 3
# waypoints 5
# waypoints 4
# waypoints 4
# waypoints 8
# waypoints 7
# waypoints 4
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 13
# waypoints 6
# waypoints 5
# waypoints 6
# waypoints 4
# waypoints 7
# waypoints 5
# waypoints 4
# waypoints 6
# waypoints 4
# waypoints 7
# waypoints 3
# waypoints 6
# waypoints 9
# waypoints 4
# waypoints 7
# waypoints 8
# waypoints 7
# waypoints 5
# waypoints 8
# waypoints 6
# waypoints 5
# waypoints 4
# waypoints 6
# waypoints 4
# waypoints 4
# waypoints 4
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 8
# waypoints 7
# waypoints 4
# waypoints 6
# waypoints 6
# waypoints 3
# waypoints 6
# waypoints 7
# waypoints 5
# waypoints 9
# waypoints 8
# waypoints 3
# waypoints 6
# waypoints 9
# waypoints 7
# waypoints 4
# waypoints 3
# waypoints 10
# waypoints 5
# waypoints 5
# waypoints 5
# waypoints 6
# waypoints 3
# waypoints 4
# waypoints 3
# waypoints 8
# waypoints 4
# waypoints 3
# waypoints 4
# waypoints 6
# waypoints 5
# waypoints 6
# waypoints 7
# waypoints 3
# waypoints 8
# waypoints 5
# waypoints 8
# waypoints 6
# waypoints 5
# waypoints 3
# waypoints 7
# waypoints 10
# waypoints 9
# waypoints 7
# waypoints 5
# waypoints 5
# waypoints 10
# waypoints 7
# waypoints 7
# waypoints 3
# waypoints 3
# waypoints 8
# waypoints 6
# waypoints 6
# waypoints 8
# waypoints 5
# waypoints 7
# waypoints 6
# waypoints 7
# waypoints 6
# waypoints 6
# waypoints 4
# waypoints 3
# waypoints 4
# waypoints 9
# waypoints 7
# waypoints 6
# waypoints 5
# waypoints 5
# waypoints 5
# waypoints 7
# waypoints 9
# waypoints 6
# waypoints 7
# waypoints 8
# waypoints 6
# waypoints 7
# waypoints 6
# waypoints 4
# waypoints 6
# waypoints 5
# waypoints 5
# waypoints 7
# waypoints 7
# waypoints 8
# waypoints 11
# waypoints 7
# waypoints 4
# waypoints 3
# waypoints 7
# waypoints 5
# waypoints 5
# waypoints 7
# waypoints 8
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 7
# waypoints 7
# waypoints 6
# waypoints 5
# waypoints 5
# waypoints 3
# waypoints 7
# waypoints 3
# waypoints 7
# waypoints 8
# waypoints 3
# waypoints 4
# waypoints 8
# waypoints 5
# waypoints 5
# waypoints 4
# waypoints 6
# waypoints 5
# waypoints 5
# waypoints 6
# waypoints 7
# waypoints 5
# waypoints 8
# waypoints 5
# waypoints 6
# waypoints 4
# waypoints 7
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 3
# waypoints 7
# waypoints 6
# waypoints 4
# waypoints 9
# waypoints 7
# waypoints 6
# waypoints 7
# waypoints 7
# waypoints 3
# waypoints 9
# waypoints 6
# waypoints 5
# waypoints 3
# waypoints 6
# waypoints 5
# waypoints 4
# waypoints 8
# waypoints 8
# waypoints 8
# waypoints 5
# waypoints 3
# waypoints 5
# waypoints 7
# waypoints 5
# waypoints 9
# waypoints 7
# waypoints 5
# waypoints 7
# waypoints 10
# waypoints 9
# waypoints 3
# waypoints 8
# waypoints 6
# waypoints 3
# waypoints 7
# waypoints 7
# waypoints 5
# waypoints 8
# waypoints 3
# waypoints 6
# waypoints 4
# waypoints 5
# waypoints 6
# waypoints 6
# waypoints 7
# waypoints 7
# waypoints 4
# waypoints 3
# waypoints 5
# waypoints 4
# waypoints 8
# waypoints 7
# waypoints 3
# waypoints 5
# waypoints 7
# waypoints 8
# waypoints 9
# waypoints 5
# waypoints 5
# waypoints 5
# waypoints 3
# waypoints 6
# waypoints 7
# waypoints 8
# waypoints 4
# waypoints 4
# waypoints 6
# waypoints 5
# waypoints 7
# waypoints 6
# waypoints 9
# waypoints 7
# waypoints 8
# waypoints 7
# waypoints 5
# waypoints 4
# waypoints 5
# waypoints 4
# waypoints 3
# waypoints 3
# waypoints 7
# waypoints 5
# waypoints 6
# waypoints 6
# waypoints 6
# waypoints 3
# waypoints 4
# waypoints 7
# waypoints 10
# waypoints 5
# waypoints 5
# waypoints 4
# waypoints 9
# waypoints 4
# waypoints 8
# waypoints 2
# waypoints 5
# waypoints 6
# waypoints 9
# waypoints 6
# waypoints 5
# waypoints 3
# waypoints 7
# waypoints 4
# waypoints 7
# waypoints 6
# waypoints 8
# waypoints 6
# waypoints 4
# waypoints 10
# waypoints 4
# waypoints 3
# waypoints 4
# waypoints 6
# waypoints 6
# waypoints 7
# waypoints 7
# waypoints 7
# waypoints 5
# waypoints 7
# waypoints 5
# waypoints 5
# waypoints 6
# waypoints 5
# waypoints 4
# waypoints 5
# waypoints 8
# waypoints 8
# waypoints 8
# waypoints 3
# waypoints 7
# waypoints 8
# waypoints 4
# waypoints 3
# waypoints 5
# waypoints 5
# waypoints 7
# waypoints 7
# waypoints 4
# waypoints 6
# waypoints 3
# waypoints 4
# waypoints 5
# waypoints 4
# waypoints 8
# waypoints 8
# waypoints 3
# waypoints 8
# waypoints 9
# waypoints 8
# waypoints 5
# waypoints 5
# waypoints 4
# waypoints 7
# waypoints 6
# waypoints 4
# waypoints 5
# waypoints 4
# waypoints 5
# waypoints 10
# waypoints 8
# waypoints 6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3612096/2714256336.py in <module>
#       7         # print ('j', j)
#       8 #         print ('train_config[i,j]', train_config[i,j])
# ----> 9         waypoints = RRTstar(obs[i], train_config[i,j])
#      10         if waypoints is not None:
#      11             print ('waypoints', waypoints.shape[0])
#
# /tmp/ipykernel_3612096/1423565831.py in RRTstar(Obstacles, configuration)
#      20 # create rrt_search
#      21     rrt = RRTStar(X, Q, x_init, x_goal, max_samples, r, prc, rewire_count)
# ---> 22     path = rrt.rrt_star()
#      23     if path is None:
#      24         return None
#
# ~/Projects/ST_LSTM_MP/Data_generator/RRT_star_3D/rrt_star.py in rrt_star(self)
#     105
#     106                     # check nearby vertices for total cost and connect shortest valid edge
# --> 107                     self.connect_shortest_valid(0, x_new, L_near)
#     108
#     109                     if x_new in self.trees[0].E:
#
# ~/Projects/ST_LSTM_MP/Data_generator/RRT_star_3D/rrt_star.py in connect_shortest_valid(self, tree, x_new, L_near)
#      69         # check nearby vertices for total cost and connect shortest valid edge
#      70         for c_near, x_near in L_near:
# ---> 71             if c_near + cost_to_go(x_near, self.x_goal) < self.c_best and self.connect_to_point(tree, x_near, x_new):
#      72                 break
#      73
#
# ~/Projects/ST_LSTM_MP/Data_generator/RRT_star_3D/rrt_base.py in connect_to_point(self, tree, x_a, x_b)
#      98         :return: bool, True if able to add edge, False if prohibited by an obstacle
#      99         """
# --> 100         if self.trees[tree].V.count(x_b) == 0 and self.X.collision_free(x_a, x_b, self.r):
#     101             self.add_vertex(tree, x_b)
#     102             self.add_edge(tree, x_b, x_a)
#
# ~/Projects/ST_LSTM_MP/Data_generator/RRT_star_3D/search_space.py in collision_free(self, start, end, r)
#      66         """
#      67         points = es_points_along_line(start, end, r)
# ---> 68         coll_free = all(map(self.obstacle_free, points))
#      69         return coll_free
#      70
#
# ~/Projects/ST_LSTM_MP/Data_generator/RRT_star_3D/search_space.py in obstacle_free(self, x)
#      45         :return: True if not inside an obstacle, False otherwise
#      46         """
# ---> 47         return self.obs.count(x) == 0
#      48
#      49     def sample_free(self):
#
# ~/anaconda3/envs/pytorch19/lib/python3.8/site-packages/rtree/index.py in count(self, coordinates)
#     520         p_num_results = ctypes.c_uint64(0)
#     521
# --> 522         core.rt.Index_Intersects_count(self.handle,
#     523                                        p_mins,
#     524                                        p_maxs,
#
# KeyboardInterrupt:

# %%
from statistics import median
train_paths = map100_train.copy()
train_seq_len = [path.shape[0] for path in train_paths]
max_train_seq_len = max(train_seq_len)
for i in range(len(train_paths)):
#     print ('paths', train_paths[i])
    curr_seq_len = train_paths[i].shape[0]
    pad_seq_len = max_train_seq_len - curr_seq_len #+ 1 #XXXX
    pad_seq = np.tile(train_paths[i][-1], (pad_seq_len, 1)) #XXXX
#     pad_seq[-1] = train_paths[i][-1] #XXXX
    train_paths[i] = np.concatenate((train_paths[i], pad_seq),axis = 0) #XXXX
#     print ('concatenate', train_paths[i])
train_paths = np.array(train_paths)
print (train_paths.shape)
    
train_file = op.join(arr_dir, "train_path.npy")
np.save(train_file, train_paths)

# with open(train_file, 'w') as file:
#     file.writelines('@'.join(str(j) for j in i) + '\n' for path in train_paths)
# Out:
# (500, 8, 3)

# %%
map100_test_seen = []
for i in range(100):
    print ('map', i)
#     for j in range(1):
    for j in range(test_seen_config.shape[1]):
            
        # print ('j', j)
        # print ('train_config[i,j]', train_config[i,j])
        waypoints = RRTstar(obs[i], test_seen_config[i,j])
        if waypoints is not None:
            map100_test_seen.append(waypoints)
        else:
            map100_test_seen.append(map100_test_seen[-1])
# Out:
# map 0
# map 1
# map 2
# map 3
# map 4
# map 5
# map 6
# map 7
# map 8
# map 9
# map 10
# map 11
# map 12
# map 13
# map 14
# map 15
# map 16
# map 17
# map 18
# map 19
# map 20
# map 21
# map 22
# map 23
# map 24
# map 25
# map 26
# map 27
# map 28
# map 29
# map 30
# map 31
# map 32
# map 33
# map 34
# map 35
# map 36
# map 37
# map 38
# map 39
# map 40
# map 41
# map 42
# map 43
# map 44
# map 45
# map 46
# map 47
# map 48
# map 49
# map 50
# map 51
# map 52
# map 53
# map 54
# map 55
# map 56
# map 57
# map 58
# map 59
# map 60
# map 61
# map 62
# map 63
# map 64
# map 65
# map 66
# map 67
# map 68
# map 69
# map 70
# map 71
# map 72
# map 73
# map 74
# map 75
# map 76
# map 77
# map 78
# map 79
# map 80
# map 81
# map 82
# map 83
# map 84
# map 85
# map 86
# map 87
# map 88
# map 89
# map 90
# map 91
# map 92
# map 93
# map 94
# map 95
# map 96
# map 97
# map 98
# map 99

# %%
test_seen_paths = map100_test_seen.copy()
test_seen_seq_len = [path.shape[0] for path in test_seen_paths]
max_test_seen_seq_len = max(test_seen_seq_len)
for i in range(len(test_seen_paths)):
    curr_seq_len = test_seen_paths[i].shape[0]
    pad_seq_len = max_test_seen_seq_len - curr_seq_len #+ 1
    pad_seq = np.tile(test_seen_paths[i][-1], (pad_seq_len, 1))
#     pad_seq[-1] = test_seen_paths[i][-1] 
    test_seen_paths[i] = np.concatenate((test_seen_paths[i], pad_seq),axis = 0)
test_seen_paths = np.array(test_seen_paths)
print (test_seen_paths.shape)
    
test_seen_file = op.join(arr_dir, "test_seen_path.npy")
np.save(test_seen_file, test_seen_paths)
# Out:
# (100, 8, 3)

# %%
map20_test_unseen = []
for i in range(100, 120):
    print ('map', i)
    for j in range(test_unseen_config.shape[1]):
        
        # print ('j', j)
        # print ('train_config[i,j]', train_config[i,j])
        waypoints = RRTstar(obs[i], test_unseen_config[i-100,j])
        if waypoints is not None:
            map20_test_unseen.append(waypoints)
        else:
            map20_test_unseen.append(map20_test_unseen[-1])

# %%
test_unseen_paths = map20_test_unseen.copy()
test_unseen_seq_len = [path.shape[0] for path in test_unseen_paths]
max_test_unseen_seq_len = max(test_unseen_seq_len)
for i in range(len(test_unseen_paths)):
    curr_seq_len = test_unseen_paths[i].shape[0]
    pad_seq_len = max_test_unseen_seq_len - curr_seq_len #+ 1
    pad_seq = np.tile(test_unseen_paths[i][-1], (pad_seq_len, 1))
#     pad_seq[-1] = test_unseen_paths[i][-1] 
    test_unseen_paths[i] = np.concatenate((test_unseen_paths[i], pad_seq),axis = 0)
test_unseen_paths = np.array(test_unseen_paths)
print (test_unseen_paths.shape)
    
test_unseen_file = op.join(arr_dir, "test_unseen_path.npy")
np.save(test_unseen_file, test_unseen_paths)
